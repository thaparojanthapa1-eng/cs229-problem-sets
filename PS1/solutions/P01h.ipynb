# %% [markdown]
# # Box-Cox Transformation which is defined as:

# %% [markdown]
# # $$x^{(\lambda)} = \begin{cases} \dfrac{x^\lambda - 1}{\lambda} & \text{if } \lambda \neq 0 \\ \log(x) & \text{if } \lambda = 0 \end{cases}$$
