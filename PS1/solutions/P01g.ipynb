# %% [markdown]
# ![Alt text](..\output\P01b_pred.png)

# %% [markdown]
# Linear regression

# %% [markdown]
# ![Alt text](..\output\P01e_pred.png)

# %% [markdown]
# GDA

# %% [markdown]
# # Here, GDA seems to perform worse than Logistic regression because the distribution isn't gaussian
